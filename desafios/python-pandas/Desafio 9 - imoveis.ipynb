# %%
import pandas as pd

# %%
#conhecendo os dados
df = pd.read_csv('dados/aluguel_residencial.csv', sep=';')
df
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 21821  Apartamento                 Méier        2      0       0    70
# 21822    Quitinete                Centro        0      0       0    27
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0      1700.0       500.0  60.0     42.50   Apartamento
# ...

# %% [markdown]
# Selecione somente os imóveis classificados com tipo 'Apartamento'

# %%
aptos = df[df['Tipo'] == 'Apartamento']
aptos
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# 7      Apartamento                Grajaú        2      1       0    70
# 8      Apartamento   Lins de Vasconcelos        3      1       1    90
# ...            ...                   ...      ...    ...     ...   ...
# 21819  Apartamento        Vila Valqueire        2      0       0    52
# 21821  Apartamento                 Méier        2      0       0    70
# 21823  Apartamento           Jacarepaguá        3      1       2    78
# 21824  Apartamento  São Francisco Xavier        2      1       0    48
# 21825  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 2       800.0       390.0  20.0     53.33   Apartamento
# ...

# %% [markdown]
# Selecione os imóveis classificados com tipos 'Casa', 'Casa de Condomínio' e 'Casa de Vila'

# %%
filtro = ['Casa', 'Casa de Condomínio', 'Casa de Vila' ]
filtro
# Out:
# ['Casa', 'Casa de Condomínio', 'Casa de Vila']

# %%
select = df['Tipo'].isin(filtro)
select
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 21821    False
# 21822    False
# 21823    False
# 21824    False
# 21825    False
# Name: Tipo, Length: 21826, dtype: bool

# %%
dados_residencial = df[select]
dados_residencial
# Out:
#                      Tipo                   Bairro  Quartos  Vagas  Suites  \
# 1                    Casa          Jardim Botânico        2      0       1
# 5      Casa de Condomínio          Barra da Tijuca        5      4       5
# 6      Casa de Condomínio                    Ramos        2      2       0
# 12     Casa de Condomínio                  Taquara        3      1       1
# 16     Casa de Condomínio          Barra da Tijuca        4      3       2
# ...                   ...                      ...      ...    ...     ...
# 21791  Casa de Condomínio  Freguesia (Jacarepaguá)        3      3       1
# 21793                Casa            Bento Ribeiro        2      1       0
# 21801  Casa de Condomínio          Barra da Tijuca        3      5       3
# 21804                Casa                   Centro        5      0       1
# 21820  Casa de Condomínio          Barra da Tijuca        5      3       4
#
#        Area    Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# ...

# %% [markdown]
# Selecione os imóveis com área entre 60 e 100 metros quadrados, incluindo os limites

# %%
df = df[df['Area'].between(60, 100)]
df
# Out:
#                      Tipo                   Bairro  Quartos  Vagas  Suites  \
# 1905                 Casa             Campo Grande        4      1       4
# 2267         Casa de Vila                    Méier        4      0       1
# 4100                 Casa             Campo Grande        4      4       4
# 6573                 Casa                Riachuelo        4      0       1
# 12864         Apartamento                  Camorim        4      1       1
# 14510                Casa       Pedra de Guaratiba        4      1       0
# 17658                Casa             Braz de Pina        4      1       0
# 17830                Casa             Campo Grande        4      1       3
# 18039  Casa de Condomínio  Freguesia (Jacarepaguá)        4      3       1
# 19505         Apartamento             Campo Grande        4      1       1
#
#        Area   Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 1905    100  1600.0         0.0   0.0     16.00          Casa
# ...

# %% [markdown]
# Selecione os imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00

# %%
df = df[(df['Quartos'] == 4) & (df['Valor'] <= 2000.00)]
df
# Out:
#                      Tipo                   Bairro  Quartos  Vagas  Suites  \
# 1905                 Casa             Campo Grande        4      1       4
# 2267         Casa de Vila                    Méier        4      0       1
# 4100                 Casa             Campo Grande        4      4       4
# 6573                 Casa                Riachuelo        4      0       1
# 12864         Apartamento                  Camorim        4      1       1
# 14510                Casa       Pedra de Guaratiba        4      1       0
# 17658                Casa             Braz de Pina        4      1       0
# 17830                Casa             Campo Grande        4      1       3
# 18039  Casa de Condomínio  Freguesia (Jacarepaguá)        4      3       1
# 19505         Apartamento             Campo Grande        4      1       1
#
#        Area   Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 1905    100  1600.0         0.0   0.0     16.00          Casa
# ...
